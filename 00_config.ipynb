# %%
# %sql
-- Configure an approved external location in your workspace if needed.
-- CREATE EXTERNAL LOCATION data_lake
--   URL '<your-approved-storage-url>'
--   WITH (STORAGE CREDENTIAL `<your-storage-credential>`)

# %%
# %sql
CREATE CATALOG IF NOT EXISTS traffic_project

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS traffic_project.raw

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS traffic_project.bronze

# %%
# %sql
CREATE VOLUME IF NOT EXISTS traffic_project.raw.stream

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS traffic_project.silver

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS traffic_project.gold
